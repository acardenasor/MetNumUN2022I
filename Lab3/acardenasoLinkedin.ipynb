# %% [markdown]
# [link en linkedin](https://www.linkedin.com/in/angela-maria-cardenas-orjuela-bb78761bb/)

# %% [markdown]
# ![acardenasocognitivaclasaaplicadadacienciaconpython.JPG](data:image/jpeg;base64,...)
